# %% [markdown]
# <a href="https://colab.research.google.com/github/rofiqohfifi28/PCVKGenap_2023/blob/main/week12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt
from google.colab.patches import cv2_imshow

# %%
jokowi = cv.imread('/content/drive/MyDrive/PCVK/Images/facedet/jokowi.jpg')
jokowi_img1 = cv.cvtColor(jokowi, cv.COLOR_BGR2RGB)
jokowi_img2 = jokowi_img1.copy()

kartini = cv.imread('/content/drive/MyDrive/PCVK/Images/facedet/kartini.jpg')
kartini_img1 = cv.cvtColor(kartini, cv.COLOR_BGR2RGB)
kartini_img2 = kartini_img1.copy()

kucing = cv.imread('/content/drive/MyDrive/PCVK/Images/facedet/mycat.jpg',0)
kucing_img1 = cv.cvtColor(kucing, cv.COLOR_BGR2RGB)
kucing_img2 = kucing_img1.copy()

mask = cv.imread('/content/drive/MyDrive/PCVK/Images/facedet/mask.png',0)
mask_img1 = cv.cvtColor(mask, cv.COLOR_BGR2RGB)
mask_img2 = mask_img1.copy()

jordan = cv.imread('/content/drive/MyDrive/PCVK/Images/facedet/mjordan.jpg',0)
jordan_img1 = cv.cvtColor(jordan, cv.COLOR_BGR2RGB)
jordan_img2 = jordan_img1.copy()

solvayconf = cv.imread('/content/drive/MyDrive/PCVK/Images/facedet/solvayconf.jpg')
solvayconf_img1 = cv.cvtColor(solvayconf, cv.COLOR_BGR2RGB)

solvayconf_img2 = solvayconf.copy()
faceCascade = cv.CascadeClassifier('/content/drive/MyDrive/PCVK/Images/facedet/haarcascade_frontalface_alt.xml')

faces_rects = faceCascade.detectMultiScale(jokowi_img2, scaleFactor = 1.2, minNeighbors = 5);
for (x,y,w,h) in faces_rects:
     cv.rectangle(jokowi_img2, (x,y),(x+w,y+h),(0,255,0),5)

faces_rects = faceCascade.detectMultiScale(kartini_img2, scaleFactor = 1.2, minNeighbors = 5);
for (x,y,w,h) in faces_rects:
     cv.rectangle(kartini_img2, (x,y),(x+w,y+h),(0,255,0),5)

faces_rects = faceCascade.detectMultiScale(kucing_img2, scaleFactor = 1.2, minNeighbors = 5);
for (x,y,w,h) in faces_rects:
     cv.rectangle(kucing_img2, (x,y),(x+w,y+h),(0,255,0), 5)

faces_rects = faceCascade.detectMultiScale(mask_img2, scaleFactor = 1.2, minNeighbors = 5);
for (x,y,w,h) in faces_rects:
     cv.rectangle(mask_img2, (x,y),(x+w,y+h),(0,255,0), 5)

faces_rects = faceCascade.detectMultiScale(jordan_img2, scaleFactor = 1.2, minNeighbors = 5);
for (x,y,w,h) in faces_rects:
     cv.rectangle(jordan_img2, (x,y),(x+w,y+h),(0,255,0), 3)

faces_rects = faceCascade.detectMultiScale(solvayconf_img2, scaleFactor = 1.2, minNeighbors = 5);
for (x,y,w,h) in faces_rects:
     cv.rectangle(solvayconf_img2, (x,y),(x+w,y+h),(0,255,0), 3)

f, axarr = plt.subplots(6, 2, figsize = (15, 10))
plt.subplot(321), plt.imshow(jokowi_img1)
plt.subplot(322), plt.imshow(jokowi_img2)

plt.subplot(323), plt.imshow(kartini_img1)
plt.subplot(324), plt.imshow(kartini_img2)

plt.subplot(325), plt.imshow(kucing_img1)
plt.subplot(326), plt.imshow(kucing_img2)

f, axarr = plt.subplots(6, 2, figsize = (15, 10))
plt.subplot(321), plt.imshow(mask_img1)
plt.subplot(322), plt.imshow(mask_img2)

plt.subplot(323), plt.imshow(jordan_img1)
plt.subplot(324), plt.imshow(jordan_img2)

plt.subplot(325), plt.imshow(solvayconf_img1)
plt.subplot(326), plt.imshow(solvayconf_img2)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-3-ff4fbf857c54> in <cell line: 27>()
#      25 faceCascade = cv.CascadeClassifier('/content/drive/MyDrive/PCVK/Images/facedet/haarcascade_frontalface_alt.xml')
#      26
# ---> 27 faces_rects = faceCascade.detectMultiScale(jokowi_img2, scaleFactor = 1.2, minNeighbors = 5);
#      28 for (x,y,w,h) in faces_rects:
#      29      cv.rectangle(jokowi_img2, (x,y),(x+w,y+h),(0,255,0),5)
#
# error: OpenCV(4.7.0) /io/opencv/modules/objdetect/src/cascadedetect.cpp:1689: error: (-215:Assertion failed) !empty() in function 'detectMultiScale'

# %%
cascade_wajah = cv.CascadeClassifier(cv.data.haarcascades + "haarcascade_frontalcatface.xml")

kucing_img = cv.imread('/content/drive/MyDrive/PCVK/Images/facedet/mycat.jpg')
kucing_gray = cv.imread('/content/drive/MyDrive/PCVK/Images/facedet/mycat.jpg', 0)

roi_wajah = cascade_wajah.detectMultiScale(kucing_gray)
for (x,y,w,h) in roi_wajah: 
  cv.rectangle(kucing_gray,  (x, y), (x+w, y+h), (255, 255, 255), 3) 

plt.figure(figsize = (10, 10))
plt.imshow(cv.cvtColor(kucing_gray, cv.COLOR_BGR2RGB))

# %%
cascade_wajah = cv.CascadeClassifier(cv.data.haarcascades + "haarcascade_eye.xml")

jokowi = cv.imread('/content/drive/MyDrive/PCVK/Images/facedet/jokowi.jpg')
jokowi_gray = cv.imread('/content/drive/MyDrive/PCVK/Images/facedet/jokowi.jpg', 0)

roi_wajah = cascade_wajah.detectMultiScale(jokowi_gray)
for (x,y,w,h) in roi_wajah: 
  cv.rectangle(jokowi_gray, (x, y), (x+w, y+h), (255, 255, 255), 3)

plt.figure(figsize = (10, 10))
plt.imshow(cv.cvtColor(jokowi_gray, cv.COLOR_BGR2RGB))

# %%
# Load the cascade
cascade_wajah = cv.CascadeClassifier('/content/drive/MyDrive/PCVK/Images/facedet/haarcascade_frontalface_alt.xml')

# Load the images
img = cv.imread('/content/drive/MyDrive/PCVK/Images/facedet/mjordan.jpg')
smile = cv.imread('/content/drive/MyDrive/PCVK/Images/facedet/smile.png', cv.IMREAD_UNCHANGED)

# Convert the images to grayscale
gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)

# Detect faces
faces = cascade_wajah.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5)

# Draw rectangle around the faces and overlay the smile image
for (x, y, w, h) in faces:
    smile_resized = cv.resize(smile, (w, h))
    img[y:y+h, x:x+w] = cv2.addWeighted(img[y:y+h, x:x+w], 1, smile_resized[:, :, 0:3], 1, 0)

# Display the images
plt.figure(figsize=(12, 6))
plt.subplot(122), plt.imshow(cv.cvtColor(img, cv.COLOR_BGR2RGB))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-6-b6ea38adfbc0> in <cell line: 12>()
#      10
#      11 # Detect faces
# ---> 12 faces = cascade_wajah.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5)
#      13
#      14 # Draw rectangle around the faces and overlay the smile image
#
# error: OpenCV(4.7.0) /io/opencv/modules/objdetect/src/cascadedetect.cpp:1689: error: (-215:Assertion failed) !empty() in function 'detectMultiScale'

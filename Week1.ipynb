# %% [markdown]
# <a href="https://colab.research.google.com/github/rofiqohfifi28/PCVKGenap_2023/blob/main/Week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow 
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# %%
#membuat list untuk menyimpan url dari beberapa  image
urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
        "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
        "https://placekitten.com/800/571"]

#baca dan tampilkan image
#loop pada tiap url image, bebrapa image dapat disimpan pada list
for url in urls:
  image = io.imread(url)
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5)
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
  final_frame = cv.hconcat((image, image_2))
  cv2_imshow(final_frame)
  print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=800x276 at 0x7F55C9B124C0>
# <PIL.Image.Image image mode=RGB size=800x286 at 0x7F55CD6C09A0>
# <PIL.Image.Image image mode=RGB size=800x286 at 0x7F55C9B124C0>

# %%
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("resolusi image: tinggi x lebar = ", tinggi,"x", lebar)
cv2_imshow(image_2)
# Out:
# resolusi image: tinggi x lebar =  286 x 400
# <PIL.Image.Image image mode=RGB size=400x286 at 0x7F55C9BA8FA0>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#membuat garis horizontal ditengah image
for y in range (lebar):
 image_3[int((tinggi)/2),y] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286 at 0x7F55C9A07520>

# %% [markdown]
# Pertanyaan
# 1. Jelaskan, mengapa pada modul praktikum ini eksekusi kode Python dilakukan menggunakan Google Colab?
#   jawaban :
#   - Karena dengan menggunakan google colab kita bisa langsung menghubungkan tugas kita langsung ke github dan dengan menggunakan google colab kita tidak perlu mengintal jupiter notebook dan lainnya.
#
# 2. Jelaskan mengenai kegunaan setiap library pada praktikum langkah ke delapan?
#  - jawaban :
# - import numpy as np berfungsi untuk menyediakan fungsi yang siap pakai untuk melakukan perhitungan saintifik.
# - import pandas as pd berfungsi membuat tabel, mengubah dimensi data, mengecek data
# - import cv2 as cv berfungsi mengolah image atau video
# - from skimage import io berfungsi sebagai pemrosesan gambar yang menerapkan algoritma
#
# - import matplotlib.pylab as plt berfungsi untuk menghasilkan angka dan menyediakan toolkit
#
# Apakah semua library tersebut harus digunakan dalam praktikum sesi ini?
#
# jawaban: semua library harus digunakan semua karena saling bersangkut pautkan
# 3. Pada uji coba langkah ke-9 terdapat potongan kode program sebagai berikut :
# - Jawaban : untuk mengubah ukuran gambar menjadi lebih kecil
#
# Apa kegunaan kode program tersebut? apa pengaruh jika tidak dilakukan?
# - Jawaban jika ukuran gambar besar kita dapat mengurangi ukuran gambar tersebut pengaruhnya dalam melakukan proses import image
# 4. Perhatikan potongan kode progam berikut :
# Apakah kegunaan kode [255,255,255] ? Jelaskan!
# - Jawaban : Untuk mengubah kode warna menjadi warna putih
# 5. Jelaskan keterkaitan antara pixel dan juga resolusi gambar yang tinggi ataupun
# rendah!
# - jawaban : Resolusi adalah jumlah pixel atau picture element yang tersusun dalam sebuah gambar digital.

# %% [markdown]
# TUGAS

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#vertical
for x in range (tinggi):
  image_3[x,int((lebar)/2)] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)

#horizontal
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)


for y in range (tinggi):
  image_3[y,int(y*(lebar/tinggi))] = [255,255,255]
  image_3[y,lebar-1-int(y*(lebar/tinggi))] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286 at 0x7F55C818A430>
# <PIL.Image.Image image mode=RGB size=800x286 at 0x7F55C818AD30>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#membuat garis horizontal ditengah image
for y in range (60,160):
 image_3[int((tinggi)/2),y] = [255,255,255]
final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286 at 0x7F55C9BA8940>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#membuat kumpulan pixel ditengah image
for y in range(60, 160): 
  for x in range (60, 160):
    image_3[x, y] = [255,255,255]
final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286 at 0x7F55C9BA8DF0>
